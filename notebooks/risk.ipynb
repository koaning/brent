# %%
from brent import DAG, Query 
from brent.examples import generate_risk_dag

dag = generate_risk_dag()
dag.plot()

# %%
q = Query(dag).given(losses=1).do(best_a1=1).given(best_a2=1)
q.plot()

# %%
q.infer()
# Out:
# {'d1': {},
#  'd2': {},
#  'best_d2': {},
#  'best_d1': {},
#  'a1': {},
#  'a2': {},
#  'a3': {},
#  'best_a2': {},
#  'best_a1': {},
#  'losses': {}}
